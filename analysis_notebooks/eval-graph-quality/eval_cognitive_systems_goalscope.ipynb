# %% [markdown]
# # Evaluate Cognitive Systems Goal Scope
#
# **Purpose**: Visually show the diversity represented by the set of Cognitive System Profiles in our database.
#
# **Rationale**:
# This is needed because when doing evaluations we will need to show and report on the quality of their interactions based on the relative to the diversity of the cognitive systems. For example, roel playing agents trained on a corpus of normative human profiles will likely do well with simular profiles but do more poorly as the cognitive system diverges from that norm. We need to be able to quantify and visualize how much divergence it can accomodate and use that measure as a proxy to understand how accomodating of diversity various cognitive systems are.

# %%
# For each cognitive system, what is the scale and complexity of the goal it can pursue?

# Rubric for assessment of "scale" and "complexity" of goals:
# - scale (self, microenvironment, environment/community, planetary, universal)
# - complexity (linear, hierarchical, simultansous, conflicting...the complexity of the structure of the goal) as represented by a graph

# Plot should have filters for features like:
# - form, embodiment, origin, size, etc.
