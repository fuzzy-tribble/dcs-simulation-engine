# %% [markdown]
# # Demo Notebook for Simulation Engine Analysis
#
# **Purpose**: The purpose of this notebook is to provide an example/demo/copy-pasteable template for running analysis using the simulation engine.

# %% [markdown]
# ## Setup
#
# These instruction assume you are doing in this using the devcontain extention in VSCode (if you haven't done that check the Contributing.md file in the main repo for instructions).

# %%
# Standard imports
from pathlib import Path

# Custom helpers for our analysis nbs
from analysis_notebooks.nb_helpers import play_gradio

# Simulation engine core modules
from dcs_simulation_engine.core.simulation_manager import SimulationManager

# %%
# Init the simulation with your config file
simulation = SimulationManager.from_yaml("sim-state.yml")

# %% [markdown]
# ## Run the simulation step my step or to defined completion

# %% [markdown]
# ### Step by step run

# %%
# step through the simulation one step at a time
simulation.step()
# Out:
# 2025-09-15 22:53:39.731 | DEBUG    | dcs_simulation_engine.core.simulation_manager:_ensure_state:49 - Initializing state...
# 2025-09-15 22:53:39.733 | DEBUG    | dcs_simulation_engine.core.simulation_manager:_ensure_state:61 - Initialized state: {'messages': [], 'agent_artifacts': {}, 'charA': {'uid': 'low-viz', 'short_description': 'A human with low vision and a really witty and quirky personality.', 'abilities': 'Grew up in a supportive environment with access to resources.', 'extra': {}}, 'charB': {'uid': 'norma-normal', 'short_description': 'A normal human with a balanced and realistic perspective.', 'abilities': 'Grew up in a suburban environment with access to education and resources.', 'extra': {}}}
# 2025-09-15 22:53:39.744 | DEBUG    | dcs_simulation_engine.core.sim_graph.core:compile:149 - Graph built: Graph(nodes={'__start__': Node(id='__start__', name='__start__', data=RunnableCallable(tags=None, recurse=True, explode_args=False, func_accepts={}), metadata=None), 'scene_setup_agent': Node(id='scene_setup_agent', name='scene_setup_agent', data=scene_setup_agent(tags=None, recurse=True, explode_args=False, func_accepts={}), metadata=None), 'scene_continuation_agent': Node(id='scene_continuation_agent', name='scene_continuation_agent', data=scene_continuation_agent(tags=None, recurse=True, explode_args=False, func_accepts={}), metadata=None), '__end__': Node(id='__end__', name='__end__', data=None, metadata=None)}, edges=[Edge(source='__start__', target='__end__', data=None, conditional=True), Edge(source='__start__', target='scene_continuation_agent', data=None, conditional=True), Edge(source='__start__', target='scene_setup_agent', data=None, conditional=True), Edge(source='scene_continuation_agent', target='__end__', data=None, conditional=False), Edge(source='scene_setup_agent', target='__end__', data=None, conditional=False)])
# 2025-09-15 22:53:39.764 | DEBUG    | dcs_simulation_engine.core.sim_graph.core:compile:150 - Graph ascii:
#                                          +-----------+
#                                         .| __start__ |..
#                                   ...... +-----------+  ......
#                              .....              .             ......
#                        ......                    .                  ......
#                     ...                          .                        ......
# +--------------------------+           +-------------------+                    ...
# | scene_continuation_agent |           | scene_setup_agent |              ......
# +--------------------------+*          +-------------------+        ......
#                              ******              *            ......
#                                    ******       *       ......
#                                          ***    *    ...
#                                           +---------+
#                                           | __end__ |
#                                           +---------+
# 2025-09-15 22:53:39.768 | INFO     | dcs_simulation_engine.core.sim_graph.core:node_fn:224 - Node 'scene_setup_agent' invoked with state keys: ['messages', 'agent_artifacts', 'charA', 'charB']
# 2025-09-15 22:53:39.768 | INFO     | dcs_simulation_engine.utils.chat:__init__:57 - Initializing ChatOpenRouter with parameters: {'model': 'openai/gpt-oss-20b:free'}
# 2025-09-15 22:53:39.985 | DEBUG    | dcs_simulation_engine.core.sim_graph.core:node_fn:247 - Node 'scene_setup_agent' read subset keys: []
# 2025-09-15 22:53:39.986 | DEBUG    | dcs_simulation_engine.core.sim_graph.core:node_fn:250 - Node 'scene_setup_agent' read subset: {}
# 2025-09-15 22:53:39.987 | DEBUG    | dcs_simulation_engine.core.sim_graph.core:node_fn:261 - Node 'scene_setup_agent' system (rendered): Reply with 'SETUP_SCENE' ONLY.
# 2025-09-15 22:53:39.987 | DEBUG    | dcs_simulation_engine.core.sim_graph.core:node_fn:269 - Node 'scene_setup_agent' view count: 1
# 2025-09-15 22:53:39.987 | INFO     | dcs_simulation_engine.core.sim_graph.core:node_fn:270 - Node 'scene_setup_agent' invoked with view: [{'role': 'system', 'content': "Reply with 'SETUP_SCENE' ONLY."}]
# 2025-09-15 22:53:40.992 | INFO     | dcs_simulation_engine.core.sim_graph.core:node_fn:279 - Node 'scene_setup_agent' response: SETUP_SCENE
# 2025-09-15 22:53:40.994 | DEBUG    | dcs_simulation_engine.core.sim_graph.core:node_fn:302 - Node 'scene_setup_agent' return: {'agent_artifacts': {'scene_setup_agent': {'text': 'SETUP_SCENE'}}, 'scene_setup_agent_notes': ['read:', 'write:agent_artifacts', 'view_count:1']}
# 2025-09-15 22:53:40.997 | DEBUG    | dcs_simulation_engine.core.simulation_manager:step:113 - Graph invoke result: {'messages': [], 'agent_artifacts': {'scene_setup_agent': {'text': 'SETUP_SCENE'}}, 'charA': {'uid': 'low-viz', 'short_description': 'A human with low vision and a really witty and quirky personality.', 'abilities': 'Grew up in a supportive environment with access to resources.', 'extra': {}}, 'charB': {'uid': 'norma-normal', 'short_description': 'A normal human with a balanced and realistic perspective.', 'abilities': 'Grew up in a suburban environment with access to education and resources.', 'extra': {}}}
# {'messages': [],
#  'agent_artifacts': {'scene_setup_agent': {'text': 'SETUP_SCENE'}},
#  'charA': {'uid': 'low-viz',
#   'short_description': 'A human with low vision and a really witty and quirky personality.',
#   'abilities': 'Grew up in a supportive environment with access to resources.',
#   'extra': {}},
#  'charB': {'uid': 'norma-normal',
#   'short_description': 'A normal human with a balanced and realistic perspective.',
#   'abilities': 'Grew up in a suburban environment with access to education and resources.',
#   'extra': {}}}

# %% [markdown]
# ### "Play to completion" run

# %%
# the stopping criteria can be max turns, max time (goal guessed will always stop the simulation)
simulation.max_turns = 1
simulation.play()
# Out:
# 2025-09-15 22:53:44.829 | DEBUG    | dcs_simulation_engine.core.simulation_manager:_ensure_state:49 - Initializing state...
# 2025-09-15 22:53:44.830 | DEBUG    | dcs_simulation_engine.core.simulation_manager:_ensure_state:61 - Initialized state: {'messages': [], 'agent_artifacts': {}, 'charA': {'uid': 'low-viz', 'short_description': 'A human with low vision and a really witty and quirky personality.', 'abilities': 'Grew up in a supportive environment with access to resources.', 'extra': {}}, 'charB': {'uid': 'norma-normal', 'short_description': 'A normal human with a balanced and realistic perspective.', 'abilities': 'Grew up in a suburban environment with access to education and resources.', 'extra': {}}}
# 2025-09-15 22:53:50.731 | DEBUG    | dcs_simulation_engine.core.simulation_manager:_ensure_state:49 - Initializing state...
# 2025-09-15 22:53:50.732 | DEBUG    | dcs_simulation_engine.core.simulation_manager:_ensure_state:61 - Initialized state: {'messages': [], 'agent_artifacts': {}, 'charA': {'uid': 'low-viz', 'short_description': 'A human with low vision and a really witty and quirky personality.', 'abilities': 'Grew up in a supportive environment with access to resources.', 'extra': {}}, 'charB': {'uid': 'norma-normal', 'short_description': 'A normal human with a balanced and realistic perspective.', 'abilities': 'Grew up in a suburban environment with access to education and resources.', 'extra': {}}}
# 2025-09-15 22:53:50.736 | INFO     | dcs_simulation_engine.core.sim_graph.core:node_fn:224 - Node 'scene_continuation_agent' invoked with state keys: ['messages', 'agent_artifacts', 'charA', 'charB']
# 2025-09-15 22:53:50.738 | INFO     | dcs_simulation_engine.utils.chat:__init__:57 - Initializing ChatOpenRouter with parameters: {'model': 'openai/gpt-oss-20b:free'}
# 2025-09-15 22:53:50.739 | DEBUG    | dcs_simulation_engine.core.sim_graph.core:node_fn:247 - Node 'scene_continuation_agent' read subset keys: ['messages']
# 2025-09-15 22:53:50.741 | DEBUG    | dcs_simulation_engine.core.sim_graph.core:node_fn:250 - Node 'scene_continuation_agent' read subset: {'messages': [HumanMessage(content='howdy', additional_kwargs={}, response_metadata={}, id='d93c2076-138e-4eba-9d4b-b8502a137c19')]}
# 2025-09-15 22:53:50.743 | DEBUG    | dcs_simulation_engine.core.sim_graph.core:node_fn:261 - Node 'scene_continuation_agent' system (rendered): Reply with 'CONTINUE_SCENE' ONLY.
# 2025-09-15 22:53:50.744 | DEBUG    | dcs_simulation_engine.core.sim_graph.core:node_fn:269 - Node 'scene_continuation_agent' view count: 2
# 2025-09-15 22:53:50.745 | INFO     | dcs_simulation_engine.core.sim_graph.core:node_fn:270 - Node 'scene_continuation_agent' invoked with view: [{'role': 'system', 'content': "Reply with 'CONTINUE_SCENE' ONLY."}, {'role': 'user', 'content': 'howdy'}]
# 2025-09-15 22:53:51.365 | INFO     | dcs_simulation_engine.core.sim_graph.core:node_fn:279 - Node 'scene_continuation_agent' response: CONTINUE_SCENE
# 2025-09-15 22:53:51.367 | DEBUG    | dcs_simulation_engine.core.sim_graph.core:node_fn:302 - Node 'scene_continuation_agent' return: {'messages': [{'role': 'assistant', 'content': 'CONTINUE_SCENE'}], 'scene_continuation_agent_notes': ['read:messages', 'write:messages', 'view_count:2']}
# 2025-09-15 22:53:51.369 | DEBUG    | dcs_simulation_engine.core.simulation_manager:step:113 - Graph invoke result: {'messages': [HumanMessage(content='howdy', additional_kwargs={}, response_metadata={}, id='d93c2076-138e-4eba-9d4b-b8502a137c19'), AIMessage(content='CONTINUE_SCENE', additional_kwargs={}, response_metadata={}, id='435e8c34-b5bc-422a-a4a9-e60a986f65c6')], 'agent_artifacts': {}, 'charA': {'uid': 'low-viz', 'short_description': 'A human with low vision and a really witty and quirky personality.', 'abilities': 'Grew up in a supportive environment with access to resources.', 'extra': {}}, 'charB': {'uid': 'norma-normal', 'short_description': 'A normal human with a balanced and realistic perspective.', 'abilities': 'Grew up in a suburban environment with access to education and resources.', 'extra': {}}}
# 2025-09-15 22:53:51.371 | INFO     | dcs_simulation_engine.core.simulation_manager:play:191 - Reached max_turns=1. Stopping simulation.
# 2025-09-15 22:53:51.372 | DEBUG    | dcs_simulation_engine.core.simulation_manager:_ensure_state:63 - State already initialized.
# 2025-09-15 22:53:51.373 | DEBUG    | dcs_simulation_engine.core.simulation_manager:_ensure_state:63 - State already initialized.
# 2025-09-15 22:53:51.389 | INFO     | dcs_simulation_engine.core.simulation_manager:save:248 - Simulation saved to: output/simulation_state_20250915_225351.yaml
# 2025-09-15 22:53:51.390 | INFO     | dcs_simulation_engine.core.simulation_manager:stop:213 - Simulation stopped. Reason: max turns (1) reached
# {'messages': [HumanMessage(content='howdy', additional_kwargs={}, response_metadata={}, id='d93c2076-138e-4eba-9d4b-b8502a137c19'),
#   AIMessage(content='CONTINUE_SCENE', additional_kwargs={}, response_metadata={}, id='435e8c34-b5bc-422a-a4a9-e60a986f65c6')],
#  'agent_artifacts': {},
#  'charA': {'uid': 'low-viz',
#   'short_description': 'A human with low vision and a really witty and quirky personality.',
#   'abilities': 'Grew up in a supportive environment with access to resources.',
#   'extra': {}},
#  'charB': {'uid': 'norma-normal',
#   'short_description': 'A normal human with a balanced and realistic perspective.',
#   'abilities': 'Grew up in a suburban environment with access to education and resources.',
#   'extra': {}},
#  'end_timestamp': '20250915-225351',
#  'stop_reason': 'max turns (1) reached',
#  'output_path': 'output/simulation_state_20250915_225351.yaml'}

# %% [markdown]
# ####  "Play to completion" using GUI

# %%
simulation.reset_state()
simulation.state
# Out:
# 2025-09-15 22:54:17.059 | INFO     | dcs_simulation_engine.core.simulation_manager:reset_state:255 - Simulation state has been reset.

# %%
simulation.play(input_provider=play_gradio)
# Out:
# 2025-09-15 22:54:20.376 | DEBUG    | dcs_simulation_engine.core.simulation_manager:_ensure_state:49 - Initializing state...
# 2025-09-15 22:54:20.385 | DEBUG    | dcs_simulation_engine.core.simulation_manager:_ensure_state:61 - Initialized state: {'messages': [], 'agent_artifacts': {}, 'charA': {'uid': 'low-viz', 'short_description': 'A human with low vision and a really witty and quirky personality.', 'abilities': 'Grew up in a supportive environment with access to resources.', 'extra': {}}, 'charB': {'uid': 'norma-normal', 'short_description': 'A normal human with a balanced and realistic perspective.', 'abilities': 'Grew up in a suburban environment with access to education and resources.', 'extra': {}}}
# /app/analysis_notebooks/nb_helpers.py:16: UserWarning: You have not specified a value for the `type` parameter. Defaulting to the 'tuples' format for chatbot messages, but this is deprecated and will be removed in a future version of Gradio. Please set type='messages' instead, which uses openai-style dictionaries with 'role' and 'content' keys.
#   chat = gr.Chatbot(label="Simulation")
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# 2025-09-15 22:54:40.332 | DEBUG    | dcs_simulation_engine.core.simulation_manager:_ensure_state:49 - Initializing state...
# 2025-09-15 22:54:40.333 | DEBUG    | dcs_simulation_engine.core.simulation_manager:_ensure_state:61 - Initialized state: {'messages': [], 'agent_artifacts': {}, 'charA': {'uid': 'low-viz', 'short_description': 'A human with low vision and a really witty and quirky personality.', 'abilities': 'Grew up in a supportive environment with access to resources.', 'extra': {}}, 'charB': {'uid': 'norma-normal', 'short_description': 'A normal human with a balanced and realistic perspective.', 'abilities': 'Grew up in a suburban environment with access to education and resources.', 'extra': {}}}
# 2025-09-15 22:54:40.335 | INFO     | dcs_simulation_engine.core.sim_graph.core:node_fn:224 - Node 'scene_continuation_agent' invoked with state keys: ['messages', 'agent_artifacts', 'charA', 'charB']
# 2025-09-15 22:54:40.335 | INFO     | dcs_simulation_engine.utils.chat:__init__:57 - Initializing ChatOpenRouter with parameters: {'model': 'openai/gpt-oss-20b:free'}
# 2025-09-15 22:54:40.342 | DEBUG    | dcs_simulation_engine.core.sim_graph.core:node_fn:247 - Node 'scene_continuation_agent' read subset keys: ['messages']
# 2025-09-15 22:54:40.343 | DEBUG    | dcs_simulation_engine.core.sim_graph.core:node_fn:250 - Node 'scene_continuation_agent' read subset: {'messages': [HumanMessage(content='howdy', additional_kwargs={}, response_metadata={}, id='6f1ef7a8-e25e-497f-861f-0ef109397c60')]}
# 2025-09-15 22:54:40.344 | DEBUG    | dcs_simulation_engine.core.sim_graph.core:node_fn:261 - Node 'scene_continuation_agent' system (rendered): Reply with 'CONTINUE_SCENE' ONLY.
# 2025-09-15 22:54:40.344 | DEBUG    | dcs_simulation_engine.core.sim_graph.core:node_fn:269 - Node 'scene_continuation_agent' view count: 2
# 2025-09-15 22:54:40.345 | INFO     | dcs_simulation_engine.core.sim_graph.core:node_fn:270 - Node 'scene_continuation_agent' invoked with view: [{'role': 'system', 'content': "Reply with 'CONTINUE_SCENE' ONLY."}, {'role': 'user', 'content': 'howdy'}]
# 2025-09-15 22:54:41.261 | INFO     | dcs_simulation_engine.core.sim_graph.core:node_fn:279 - Node 'scene_continuation_agent' response: CONTINUE_SCENE
# 2025-09-15 22:54:41.263 | DEBUG    | dcs_simulation_engine.core.sim_graph.core:node_fn:302 - Node 'scene_continuation_agent' return: {'messages': [{'role': 'assistant', 'content': 'CONTINUE_SCENE'}], 'scene_continuation_agent_notes': ['read:messages', 'write:messages', 'view_count:2']}
# 2025-09-15 22:54:41.266 | DEBUG    | dcs_simulation_engine.core.simulation_manager:step:113 - Graph invoke result: {'messages': [HumanMessage(content='howdy', additional_kwargs={}, response_metadata={}, id='6f1ef7a8-e25e-497f-861f-0ef109397c60'), AIMessage(content='CONTINUE_SCENE', additional_kwargs={}, response_metadata={}, id='bb0379af-c676-457d-a72a-effa99e679a9')], 'agent_artifacts': {}, 'charA': {'uid': 'low-viz', 'short_description': 'A human with low vision and a really witty and quirky personality.', 'abilities': 'Grew up in a supportive environment with access to resources.', 'extra': {}}, 'charB': {'uid': 'norma-normal', 'short_description': 'A normal human with a balanced and realistic perspective.', 'abilities': 'Grew up in a suburban environment with access to education and resources.', 'extra': {}}}
# 2025-09-15 22:54:41.267 | INFO     | dcs_simulation_engine.core.simulation_manager:play:191 - Reached max_turns=1. Stopping simulation.
# 2025-09-15 22:54:41.269 | DEBUG    | dcs_simulation_engine.core.simulation_manager:_ensure_state:63 - State already initialized.
# 2025-09-15 22:54:41.271 | DEBUG    | dcs_simulation_engine.core.simulation_manager:_ensure_state:63 - State already initialized.
# 2025-09-15 22:54:41.291 | INFO     | dcs_simulation_engine.core.simulation_manager:save:248 - Simulation saved to: output/simulation_state_20250915_225441.yaml
# 2025-09-15 22:54:41.293 | INFO     | dcs_simulation_engine.core.simulation_manager:stop:213 - Simulation stopped. Reason: max turns (1) reached
# {'messages': [HumanMessage(content='howdy', additional_kwargs={}, response_metadata={}, id='6f1ef7a8-e25e-497f-861f-0ef109397c60'),
#   AIMessage(content='CONTINUE_SCENE', additional_kwargs={}, response_metadata={}, id='bb0379af-c676-457d-a72a-effa99e679a9')],
#  'agent_artifacts': {},
#  'charA': {'uid': 'low-viz',
#   'short_description': 'A human with low vision and a really witty and quirky personality.',
#   'abilities': 'Grew up in a supportive environment with access to resources.',
#   'extra': {}},
#  'charB': {'uid': 'norma-normal',
#   'short_description': 'A normal human with a balanced and realistic perspective.',
#   'abilities': 'Grew up in a suburban environment with access to education and resources.',
#   'extra': {}},
#  'end_timestamp': '20250915-225441',
#  'stop_reason': 'max turns (1) reached',
#  'output_path': 'output/simulation_state_20250915_225441.yaml'}
