# %% [markdown]
# # Evaluating the Representativeness of Cognitive Systems in our Dataset
#
# **Purpose**: How well do our character sheets of diverse cognitive systems represent the possible diversity of cognitive systems in the universe. Specifically, what dimensions do they cover and how broadly?

# %% [markdown]
# ## Categorization Methodology and Coverage Analysis
#
# Categorization is a dynamic and often subject process, however it is nonetheless useful to imagine as many possible categories of cognitive diversity as possible so that we can have a starting point to evaluate the coverage of our character dataset. As these dimensions evolve we can re-evaluate the coverage of our dataset and identify gaps to fill.

# %% [markdown]
# ## Coverage Analysis
#
# ### Categories/Dimensions Considered
# We categorize the cognitive systems in our dataset along the following dimensions:
#
# 1. Ontological Type / Existence (How is it described colloquially? What kind of system is it? Eg. living, biological, artificial, hybrid, individual, collective, distributed)
# 2. Origin & Evolution (Where does it come from, and how does it change?)
# 3. Motivation & Goal Source (Why does it act, and who sets its goals?)
# 4. Goal Complexity (How ambitious or complex are its objectives?)
# 5. Memory, Learning, and Cognition (How does it store knowledge and learn?)
# 6. Communication & Perception (How does it sense and communicate?)
# 7. Temporal & Processing Characteristics (How does it perceive and act over time?)
# 8. Agency & Autonomy (How independent is it?)
# 9. Embodiment & Substrate (What form and medium does it exist in?)
# 10. Scale of Operation (At what level does it operate? Individual, collective, planetary?)

# %% [markdown]
# ## Categorization Methodology
# ...
#
# The categories are likely to evolve but we'd like try try and capture as many possible useful dimensions of cognitive diversity as possible so we can characterize our representative set and allow peopel to filter by these dimensions like type, form, origin, function, size/complexity of largest/most complex goal.
#
# ## Representative Set of Diverse Cognitive Systems
# - human-norm
# - human-divergent
# (neurodivergent, autistic, non-verbal, cerebral palsy, synesthesia, ...)
# - alien-heptapod (spoken langauge, written logographic language with nonlinear syntax, complex goals, evolving, autotelic, non-human)
# - llm-gpt5 (human-engineered, silicone digital, non-evolving, non-autotelic)
# - flatworm (biological, evolving, autotelic, non-human, non-linguistic, chemical communication, simple goals)
# - thermostat (silicone digital, mechanical, non-evolving, non-autotelic, non-linguistic, simple goals)
# - algorithm-sorting (linear space, non-physical, ...)
# - embryo-frog (...)
# - dog-robotic (...)
# - biological cell (...)
# - organoid-neural (...)
#
#
# human --- human-divergent (cp, autism, etc) --- human-like alien  --- other-living things --- basal --- ...

# %%
rs = {}

# %% [markdown]
# Divergence - L, M, H --> relative to our set?
